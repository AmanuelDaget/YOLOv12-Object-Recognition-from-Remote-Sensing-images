# %% [markdown]
# <a href="https://colab.research.google.com/github/AmanuelDaget/YOLOv12-Object-Recognition-from-Remote-Sensing-images/blob/main/data_organization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import shutil
from pathlib import Path

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT = Path("/content/drive/MyDrive/Colab Notebooks/Computer Vision and Image Processing/Object-detection-using-YOLOv12")

for split in ["training", "test"]:

    split_path = ROOT / split

    images_dir = split_path / "images"
    labels_dir = split_path / "labels"

    # FIX: add parents=True
    images_dir.mkdir(parents=True, exist_ok=True)
    labels_dir.mkdir(parents=True, exist_ok=True)

    for file in split_path.iterdir():

        if file.is_file():

            if file.suffix.lower() in [".jpg", ".jpeg", ".png"]:

                shutil.move(str(file), images_dir / file.name)

            elif file.suffix.lower() == ".txt":

                shutil.move(str(file), labels_dir / file.name)

print("Dataset reorganized successfully.")
# Out:
# Dataset reorganized successfully.

# %%
for split in ['training', 'val', 'test']:
    imgs = len(list((Path(ROOT)/split/'images').glob('*.jpg')))
    lbls = len(list((Path(ROOT)/split/'labels').glob('*.txt')))
    print(f"  {split:5s} → images: {imgs:6d} | labels: {lbls:6d} | match: {'✅' if imgs==lbls else '❌'}")
# Out:
#   training → images:   4000 | labels:   4000 | match: ✅
#   val   → images:      0 | labels:      0 | match: ✅
#   test  → images:   1000 | labels:   1000 | match: ✅
